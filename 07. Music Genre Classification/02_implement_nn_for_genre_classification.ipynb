# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split   
import tensorflow.keras as keras

# %%
DATASET_PATH = "audio_data.json"

# %%
def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)

    # convert lists into numpy arrays
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])

    return inputs, targets

# %%
if __name__ == "__main__":
    # load data
    inputs, targets = load_data(DATASET_PATH)

    # split the data into train and test sets
    inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)  

    # build the network architecture
    model = keras.Sequential([
        # input layer
        keras.layers.Flatten(input_shape=(inputs.shape[1], inputs.shape[2])),

        # 1st hidden layer
        keras.layers.Dense(512, activation="relu"),

        # 2nd hidden layer
        keras.layers.Dense(256, activation="relu"),

        # 3rd hidden layer
        keras.layers.Dense(64, activation="relu"),

        # output layer (neuron_count=10)
        keras.layers.Dense(10, activation="softmax")
    ])

    # compile network
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                 loss="sparse_categorical_crossentropy",
                 metrics=["accuracy"])    

    model.summary()

    # train network
    model.fit(inputs_train, targets_train,
              validation_data=(inputs_test, targets_test),
              epochs=50,
              batch_size=32)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 1690)              0
#
#  dense_7 (Dense)             (None, 512)               865792
#
#  dense_8 (Dense)             (None, 256)               131328
#
#  dense_9 (Dense)             (None, 64)                16448
#
#  dense_10 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 219/219 [==============================] - 3s 5ms/step - loss: 8.4415 - accuracy: 0.3237 - val_loss: 4.2940 - val_accuracy: 0.3675
# Epoch 2/50
# 219/219 [==============================] - 1s 4ms/step - loss: 3.1507 - accuracy: 0.4132 - val_loss: 3.0394 - val_accuracy: 0.3828
# Epoch 3/50
# 219/219 [==============================] - 1s 4ms/step - loss: 2.1526 - accuracy: 0.4817 - val_loss: 3.0319 - val_accuracy: 0.4022
# Epoch 4/50
# 219/219 [==============================] - 1s 4ms/step - loss: 1.7424 - accuracy: 0.5233 - val_loss: 2.4557 - val_accuracy: 0.4352
# Epoch 5/50
# 219/219 [==============================] - 1s 4ms/step - loss: 1.4427 - accuracy: 0.5817 - val_loss: 2.4348 - val_accuracy: 0.4209
# Epoch 6/50
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2616 - accuracy: 0.6193 - val_loss: 2.2317 - val_accuracy: 0.4680
# Epoch 7/50
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0659 - accuracy: 0.6622 - val_loss: 2.2460 - val_accuracy: 0.4569
# Epoch 8/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.9263 - accuracy: 0.6994 - val_loss: 2.5011 - val_accuracy: 0.4513
# Epoch 9/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.8361 - accuracy: 0.7256 - val_loss: 2.2391 - val_accuracy: 0.4836
# Epoch 10/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.7286 - accuracy: 0.7574 - val_loss: 2.0362 - val_accuracy: 0.5110
# Epoch 11/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.6457 - accuracy: 0.7845 - val_loss: 2.1000 - val_accuracy: 0.5103
# Epoch 12/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.5716 - accuracy: 0.8076 - val_loss: 2.1025 - val_accuracy: 0.5063
# Epoch 13/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.5441 - accuracy: 0.8186 - val_loss: 2.1395 - val_accuracy: 0.5070
# Epoch 14/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.5177 - accuracy: 0.8269 - val_loss: 2.0539 - val_accuracy: 0.5334
# Epoch 15/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.4146 - accuracy: 0.8618 - val_loss: 2.0882 - val_accuracy: 0.5304
# Epoch 16/50
# 219/219 [==============================] - 1s 6ms/step - loss: 0.3962 - accuracy: 0.8678 - val_loss: 2.2110 - val_accuracy: 0.5093
# Epoch 17/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.3385 - accuracy: 0.8864 - val_loss: 2.2246 - val_accuracy: 0.5421
# Epoch 18/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.3116 - accuracy: 0.8943 - val_loss: 2.1772 - val_accuracy: 0.5491
# Epoch 19/50
# 219/219 [==============================] - 1s 6ms/step - loss: 0.2930 - accuracy: 0.9029 - val_loss: 2.2157 - val_accuracy: 0.5264
# Epoch 20/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2766 - accuracy: 0.9100 - val_loss: 2.3151 - val_accuracy: 0.5424
# Epoch 21/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.2981 - accuracy: 0.9060 - val_loss: 2.2628 - val_accuracy: 0.5337
# Epoch 22/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2427 - accuracy: 0.9232 - val_loss: 2.2531 - val_accuracy: 0.5444
# Epoch 23/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2085 - accuracy: 0.9286 - val_loss: 2.3081 - val_accuracy: 0.5404
# Epoch 24/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2561 - accuracy: 0.9149 - val_loss: 2.2382 - val_accuracy: 0.5567
# Epoch 25/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.2194 - accuracy: 0.9300 - val_loss: 2.2867 - val_accuracy: 0.5554
# Epoch 26/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.1808 - accuracy: 0.9369 - val_loss: 2.3001 - val_accuracy: 0.5631
# Epoch 27/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.1425 - accuracy: 0.9561 - val_loss: 2.3774 - val_accuracy: 0.5698
# Epoch 28/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.2023 - accuracy: 0.9332 - val_loss: 2.5060 - val_accuracy: 0.5501
# Epoch 29/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.1460 - accuracy: 0.9534 - val_loss: 2.2973 - val_accuracy: 0.5664
# Epoch 30/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.1064 - accuracy: 0.9697 - val_loss: 2.3933 - val_accuracy: 0.5664
# Epoch 31/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.1967 - accuracy: 0.9408 - val_loss: 2.6507 - val_accuracy: 0.5377
# Epoch 32/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2541 - accuracy: 0.9109 - val_loss: 2.6900 - val_accuracy: 0.5524
# Epoch 33/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.1800 - accuracy: 0.9389 - val_loss: 2.4340 - val_accuracy: 0.5771
# Epoch 34/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.1018 - accuracy: 0.9677 - val_loss: 2.3583 - val_accuracy: 0.5878
# Epoch 35/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0710 - accuracy: 0.9808 - val_loss: 2.5387 - val_accuracy: 0.5651
# Epoch 36/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0865 - accuracy: 0.9751 - val_loss: 2.6568 - val_accuracy: 0.5698
# Epoch 37/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.2216 - accuracy: 0.9285 - val_loss: 2.7423 - val_accuracy: 0.5651
# Epoch 38/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.1157 - accuracy: 0.9628 - val_loss: 2.4722 - val_accuracy: 0.5858
# Epoch 39/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0514 - accuracy: 0.9871 - val_loss: 2.4277 - val_accuracy: 0.6021
# Epoch 40/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0182 - accuracy: 0.9974 - val_loss: 2.5067 - val_accuracy: 0.5935
# Epoch 41/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.1684 - accuracy: 0.9486 - val_loss: 2.6548 - val_accuracy: 0.5434
# Epoch 42/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2697 - accuracy: 0.9149 - val_loss: 2.5706 - val_accuracy: 0.5681
# Epoch 43/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0945 - accuracy: 0.9708 - val_loss: 2.5626 - val_accuracy: 0.5908
# Epoch 44/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0417 - accuracy: 0.9890 - val_loss: 2.4087 - val_accuracy: 0.6035
# Epoch 45/50
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0263 - accuracy: 0.9941 - val_loss: 2.4664 - val_accuracy: 0.6008
# Epoch 46/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0286 - accuracy: 0.9921 - val_loss: 2.6541 - val_accuracy: 0.5921
# Epoch 47/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.2794 - accuracy: 0.9176 - val_loss: 2.9096 - val_accuracy: 0.5454
# Epoch 48/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.2264 - accuracy: 0.9310 - val_loss: 2.4926 - val_accuracy: 0.5928
# Epoch 49/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0690 - accuracy: 0.9803 - val_loss: 2.7143 - val_accuracy: 0.5781
# Epoch 50/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0282 - accuracy: 0.9940 - val_loss: 2.5354 - val_accuracy: 0.6045
